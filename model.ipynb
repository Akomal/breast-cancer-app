# %%
import pandas as pd
import numpy as np # linear algebra
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\KomalA\Downloads\breast_cancer.csv")
data.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# 0  ...          17.33           184.60      2019.0            0.1622
# 1  ...          23.41           158.80      1956.0            0.1238
# 2  ...          25.53           152.50      1709.0            0.1444
# 3  ...          26.50            98.87       567.7            0.2098
# 4  ...          16.67           152.20      1575.0            0.1374
#
#    compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    fractal_dimension_worst  Unnamed: 32
# 0                  0.11890          NaN
# 1                  0.08902          NaN
# 2                  0.08758          NaN
# 3                  0.17300          NaN
# 4                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
#drop the unneccessary columns to reduce curse of dimensionality
data.drop(['id','Unnamed: 32'],axis=1, inplace=True)

data.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         M        17.99         10.38          122.80     1001.0
# 1         M        20.57         17.77          132.90     1326.0
# 2         M        19.69         21.25          130.00     1203.0
# 3         M        11.42         20.38           77.58      386.1
# 4         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
data["diagnosis"].replace({"M": 0, "B": 1}, inplace=True)
data.head()
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          0        17.99         10.38          122.80     1001.0
# 1          0        20.57         17.77          132.90     1326.0
# 2          0        19.69         21.25          130.00     1203.0
# 3          0        11.42         20.38           77.58      386.1
# 4          0        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
from sklearn.datasets import load_boston
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.api as sm
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import RFE
from sklearn.linear_model import RidgeCV, LassoCV, Ridge, Lasso

# %%
#Using Pearson Correlation
plt.figure(figsize=(12,10))
cor = data.corr()
sns.heatmap(cor, annot=True, cmap=plt.cm.Reds)
plt.show()

# %%
#Correlation with output variable
cor_target = abs(cor["diagnosis"])
#Selecting highly correlated features
relevant_features = cor_target[cor_target>0.7]
relevant_features
# Out:
# diagnosis               1.000000
# radius_mean             0.730029
# perimeter_mean          0.742636
# area_mean               0.708984
# concave points_mean     0.776614
# radius_worst            0.776454
# perimeter_worst         0.782914
# area_worst              0.733825
# concave points_worst    0.793566
# Name: diagnosis, dtype: float64

# %%
y = data['diagnosis']

# %%
X = data[['area_mean', 'radius_mean', 'perimeter_mean','concave points_mean']].copy()

# %%
X
# Out:
#      area_mean  radius_mean  perimeter_mean  concave points_mean
# 0       1001.0        17.99          122.80              0.14710
# 1       1326.0        20.57          132.90              0.07017
# 2       1203.0        19.69          130.00              0.12790
# 3        386.1        11.42           77.58              0.10520
# 4       1297.0        20.29          135.10              0.10430
# ..         ...          ...             ...                  ...
# 564     1479.0        21.56          142.00              0.13890
# 565     1261.0        20.13          131.20              0.09791
# 566      858.1        16.60          108.30              0.05302
# 567     1265.0        20.60          140.10              0.15200
# 568      181.0         7.76           47.92              0.00000
#
# [569 rows x 4 columns]

# %%
#Normalization
X = (X - np.min(X))/(np.max(X)-np.min(X)).values

# %%
X
# Out:
#      area_mean  radius_mean  perimeter_mean  concave points_mean
# 0     0.363733     0.521037        0.545989             0.731113
# 1     0.501591     0.643144        0.615783             0.348757
# 2     0.449417     0.601496        0.595743             0.635686
# 3     0.102906     0.210090        0.233501             0.522863
# 4     0.489290     0.629893        0.630986             0.518390
# ..         ...          ...             ...                  ...
# 564   0.566490     0.690000        0.678668             0.690358
# 565   0.474019     0.622320        0.604036             0.486630
# 566   0.303118     0.455251        0.445788             0.263519
# 567   0.475716     0.644564        0.665538             0.755467
# 568   0.015907     0.036869        0.028540             0.000000
#
# [569 rows x 4 columns]

# %%
X = X.rename(columns={'area_mean': 'Area', 'radius_mean': 'Radius', 'perimeter_mean': 'Perimeter', 'concave points_mean': 'concave_points'})

# %%
X
# Out:
#          Area    Radius  Perimeter  concave_points
# 0    0.363733  0.521037   0.545989        0.731113
# 1    0.501591  0.643144   0.615783        0.348757
# 2    0.449417  0.601496   0.595743        0.635686
# 3    0.102906  0.210090   0.233501        0.522863
# 4    0.489290  0.629893   0.630986        0.518390
# ..        ...       ...        ...             ...
# 564  0.566490  0.690000   0.678668        0.690358
# 565  0.474019  0.622320   0.604036        0.486630
# 566  0.303118  0.455251   0.445788        0.263519
# 567  0.475716  0.644564   0.665538        0.755467
# 568  0.015907  0.036869   0.028540        0.000000
#
# [569 rows x 4 columns]

# %%
#model training using cross validation
from sklearn import svm
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import train_test_split



scores = []
model = svm.SVC(kernel='linear')
cv = StratifiedKFold(n_splits=10, random_state=None) 
for train_index, test_index in cv.split(X,y):
    X_train, X_test, y_train, y_test = X.iloc[train_index], X.iloc[test_index],y.iloc[train_index], y.iloc[test_index]
    model.fit(X_train, y_train)
    scores.append(model.score(X_test, y_test))

# %%
#calculating model accuracy
Accuracy=np.mean(scores)
print(Accuracy)
# Out:
# 0.9121867167919799

# %%
import pickle
pickle_out=open("cancer-app.pkl","wb")
pickle.dump(model,pickle_out)
pickle_out.close()

# %%
model.predict([[0.731113,0.620776,0.668310,0.912027]])
# Out:
# array([0], dtype=int64)
